# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import us
from numpy import where

# %%
# Reading in New York Times mask use by county data.
mask = pd.read_csv('./data/mask-use-by-county.csv')

# %%
mask.head()
mask['STCOUNTYFP'] = mask['COUNTYFP']

# %%
# reading in fips data set. `us` module would have done the trick if I had found it earlier!
fips = pd.read_csv('./data/ZIP-COUNTY-FIPS_2018-03.csv')

# %%
fips.head()
# Out:
#      ZIP  STCOUNTYFP           CITY STATE      COUNTYNAME CLASSFP
# 0  36091        1001        Verbena    AL  Autauga County      H1
# 1  36758        1001  Plantersville    AL  Autauga County      H1
# 2  36006        1001    Billingsley    AL  Autauga County      H1
# 3  36067        1001     Prattville    AL  Autauga County      H1
# 4  36701        1001          Selma    AL  Autauga County      H1

# %%
mask.shape
# Out:
# (3142, 7)

# %%
# Selecting columns that we need to convert FIPs into county names
fips_dict = fips[['STCOUNTYFP', 'STATE', 'COUNTYNAME']]

# %%
# Getting rid of extraneous lines
fips_dict.drop_duplicates(inplace=True)
# Out:
# /Users/alexander.fioto/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fips_dict['STATE'].value_counts()
# Out:
# TX    254
# GA    159
# VA    133
# KY    120
# MO    115
# KS    105
# IL    102
# NC    100
# IA     99
# TN     95
# NE     93
# IN     92
# OH     88
# MN     87
# MI     83
# MS     82
# PR     78
# OK     77
# AR     75
# WI     72
# PA     67
# FL     67
# AL     67
# SD     65
# LA     64
# CO     64
# NY     62
# CA     58
# MT     56
# WV     55
# ND     53
# SC     46
# ID     44
# WA     39
# OR     36
# NM     33
# UT     29
# AK     28
# MD     24
# WY     23
# NJ     21
# NV     17
# ME     16
# AZ     15
# MA     14
# VT     14
# NH     10
# CT      8
# RI      5
# HI      5
# DE      3
# VI      3
# DC      1
# GU      1
# Name: STATE, dtype: int64

# %%
# Merging masks with fips to id counties
counties = pd.merge(mask, fips_dict, on='STCOUNTYFP')

# %%
counties.drop('STCOUNTYFP', inplace=True, axis=1)

# %%
counties.head()
# Out:
#    COUNTYFP  NEVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS STATE  \
# 0      1001  0.053   0.074      0.134       0.295   0.444    AL
# 1      1003  0.083   0.059      0.098       0.323   0.436    AL
# 2      1005  0.067   0.121      0.120       0.201   0.491    AL
# 3      1007  0.020   0.034      0.096       0.278   0.572    AL
# 4      1009  0.053   0.114      0.180       0.194   0.459    AL
#
#        COUNTYNAME
# 0  Autauga County
# 1  Baldwin County
# 2  Barbour County
# 3     Bibb County
# 4   Blount County

# %%
# Saving county dataframe as county.csv
counties.to_csv('./data/county.csv')

# %%
# Quick EDA of distributions
sns.histplot(counties['NEVER'], color='red', alpha=.5);
sns.histplot(counties['SOMETIMES'], color='yellow', alpha=.5)
sns.histplot(counties['FREQUENTLY'], color='purple', alpha=.5)
sns.histplot(counties['ALWAYS'], color='green', alpha=.5);

# %% [markdown]
# **States with the highest NEVER mask score**

# %%
counties.groupby('STATE').mean().sort_values('NEVER', ascending=False).head(10)
# Out:
#            COUNTYFP     NEVER    RARELY  SOMETIMES  FREQUENTLY    ALWAYS
# STATE
# ND     38053.000000  0.180981  0.164019   0.145925    0.251811  0.257245
# WY     56023.000000  0.151609  0.157000   0.123000    0.232000  0.336435
# MT     30056.000000  0.150857  0.171589   0.144893    0.215143  0.317536
# SD     46067.430769  0.148292  0.105523   0.167108    0.218138  0.361031
# MO     29117.713043  0.134061  0.127165   0.151652    0.210539  0.376557
# NE     31093.000000  0.123806  0.117710   0.145753    0.261312  0.351452
# KS     20105.000000  0.116886  0.116943   0.151114    0.219467  0.395590
# TN     47095.000000  0.110042  0.101358   0.151958    0.209526  0.427189
# IA     19099.000000  0.104323  0.117323   0.167424    0.214707  0.396202
# ID     16044.000000  0.103773  0.144795   0.144773    0.219841  0.386841

# %%
# Adding two columns: mask_negative and mask_positive. Gathering positive and negative sentiment.
counties['mask_negative'] = counties['NEVER'] + counties['RARELY']
counties['mask_positive'] = counties['FREQUENTLY'] + counties['ALWAYS']

# %% [markdown]
# **Top 10 Mask Negative States**

# %%
counties.groupby('STATE').mean().sort_values('mask_negative', ascending=False).head(10)
# Out:
#            COUNTYFP     NEVER    RARELY  SOMETIMES  FREQUENTLY    ALWAYS  \
# STATE
# ND     38053.000000  0.180981  0.164019   0.145925    0.251811  0.257245
# MT     30056.000000  0.150857  0.171589   0.144893    0.215143  0.317536
# WY     56023.000000  0.151609  0.157000   0.123000    0.232000  0.336435
# MO     29117.713043  0.134061  0.127165   0.151652    0.210539  0.376557
# SD     46067.430769  0.148292  0.105523   0.167108    0.218138  0.361031
# ID     16044.000000  0.103773  0.144795   0.144773    0.219841  0.386841
# NE     31093.000000  0.123806  0.117710   0.145753    0.261312  0.351452
# KS     20105.000000  0.116886  0.116943   0.151114    0.219467  0.395590
# MN     27087.000000  0.103195  0.122333   0.155701    0.243126  0.375529
# IA     19099.000000  0.104323  0.117323   0.167424    0.214707  0.396202
#
#        mask_negative  mask_positive
# STATE
# ND          0.345000       0.509057
# MT          0.322446       0.532679
# WY          0.308609       0.568435
# MO          0.261226       0.587096
# SD          0.253815       0.579169
# ID          0.248568       0.606682
# NE          0.241516       0.612763
# KS          0.233829       0.615057
# MN          0.225529       0.618655
# IA          0.221646       0.610909

# %% [markdown]
# **Top 10 Mask Positive States**

# %%
counties.groupby('STATE').mean().sort_values('mask_positive', ascending=False).head(10)
# Out:
#            COUNTYFP     NEVER    RARELY  SOMETIMES  FREQUENTLY    ALWAYS  \
# STATE
# RI     44005.000000  0.012200  0.009600   0.040000    0.136000  0.802000
# HI     15005.000000  0.016200  0.018800   0.033400    0.116600  0.815000
# MA     25014.000000  0.019500  0.011786   0.040143    0.131143  0.797286
# DE     10003.000000  0.019333  0.006667   0.060667    0.095667  0.817667
# DC     11001.000000  0.012000  0.013000   0.069000    0.164000  0.743000
# NJ     34021.000000  0.022905  0.021238   0.049429    0.157905  0.748429
# CT      9008.000000  0.017500  0.023000   0.053625    0.126375  0.779500
# NY     36062.000000  0.022839  0.022452   0.049387    0.135274  0.769935
# MD     24044.958333  0.022917  0.020917   0.051542    0.161833  0.742750
# CA      6058.000000  0.032310  0.030724   0.063690    0.158603  0.714638
#
#        mask_negative  mask_positive
# STATE
# RI          0.021800       0.938000
# HI          0.035000       0.931600
# MA          0.031286       0.928429
# DE          0.026000       0.913333
# DC          0.025000       0.907000
# NJ          0.044143       0.906333
# CT          0.040500       0.905875
# NY          0.045290       0.905210
# MD          0.043833       0.904583
# CA          0.063034       0.873241

# %% [markdown]
# **Creating a state DataFrame to work with**

# %%
state = counties.groupby('STATE').mean()
state = state.drop(columns=['COUNTYFP'])

# %%
state.drop('index', axis=1)
# Out:
#    STATE     NEVER    RARELY  SOMETIMES  FREQUENTLY    ALWAYS  mask_negative  \
# 0     AK  0.053429  0.064643   0.092821    0.326393  0.462571       0.118071
# 1     AL  0.081567  0.081090   0.146612    0.215343  0.475313       0.162657
# 2     AR  0.090920  0.087253   0.138360    0.220627  0.462867       0.178173
# 3     AZ  0.049667  0.053200   0.094667    0.147333  0.655000       0.102867
# 4     CA  0.032310  0.030724   0.063690    0.158603  0.714638       0.063034
# 5     CO  0.039156  0.071937   0.097266    0.244328  0.547437       0.111094
# 6     CT  0.017500  0.023000   0.053625    0.126375  0.779500       0.040500
# 7     DC  0.012000  0.013000   0.069000    0.164000  0.743000       0.025000
# 8     DE  0.019333  0.006667   0.060667    0.095667  0.817667       0.026000
# 9     FL  0.055254  0.057522   0.110343    0.194299  0.582552       0.112776
# 10    GA  0.083333  0.078377   0.126145    0.199792  0.512314       0.161711
# 11    HI  0.016200  0.018800   0.033400    0.116600  0.815000       0.035000
# 12    IA  0.104323  0.117323   0.167424    0.214707  0.396202       0.221646
# 13    ID  0.103773  0.144795   0.144773    0.219841  0.386841       0.248568
# 14    IL  0.072275  0.071314   0.126873    0.219490  0.510078       0.143588
# 15    IN  0.086098  0.096435   0.130424    0.236924  0.450217       0.182533
# 16    KS  0.116886  0.116943   0.151114    0.219467  0.395590       0.233829
# 17    KY  0.086333  0.083125   0.131092    0.207992  0.491400       0.169458
# 18    LA  0.082328  0.072453   0.114406    0.207156  0.523656       0.154781
# 19    MA  0.019500  0.011786   0.040143    0.131143  0.797286       0.031286
# 20    MD  0.022917  0.020917   0.051542    0.161833  0.742750       0.043833
# 21    ME  0.047500  0.058938   0.100062    0.201250  0.592375       0.106437
# 22    MI  0.044795  0.061265   0.100289    0.218880  0.574807       0.106060
# 23    MN  0.103195  0.122333   0.155701    0.243126  0.375529       0.225529
# 24    MO  0.134061  0.127165   0.151652    0.210539  0.376557       0.261226
# 25    MS  0.067817  0.084488   0.119537    0.201232  0.526878       0.152305
# 26    MT  0.150857  0.171589   0.144893    0.215143  0.317536       0.322446
# 27    NC  0.053780  0.046560   0.098030    0.198320  0.603310       0.100340
# 28    ND  0.180981  0.164019   0.145925    0.251811  0.257245       0.345000
# 29    NE  0.123806  0.117710   0.145753    0.261312  0.351452       0.241516
# 30    NH  0.055100  0.057600   0.073500    0.187600  0.626300       0.112700
# 31    NJ  0.022905  0.021238   0.049429    0.157905  0.748429       0.044143
# 32    NM  0.042182  0.049636   0.078606    0.159697  0.670000       0.091818
# 33    NV  0.029294  0.041824   0.106765    0.193588  0.628647       0.071118
# 34    NY  0.022839  0.022452   0.049387    0.135274  0.769935       0.045290
# 35    OH  0.091455  0.101705   0.150273    0.217682  0.438852       0.193159
# 36    OK  0.100364  0.120792   0.166636    0.226065  0.386104       0.221156
# 37    OR  0.036667  0.049000   0.085611    0.188194  0.640417       0.085667
# 38    PA  0.035836  0.035388   0.086254    0.170657  0.671970       0.071224
# 39    RI  0.012200  0.009600   0.040000    0.136000  0.802000       0.021800
# 40    SC  0.097130  0.070543   0.109283    0.190261  0.532826       0.167674
# 41    SD  0.148292  0.105523   0.167108    0.218138  0.361031       0.253815
# 42    TN  0.110042  0.101358   0.151958    0.209526  0.427189       0.211400
# 43    TX  0.051890  0.059677   0.097193    0.188665  0.602559       0.111567
# 44    UT  0.093069  0.096966   0.118276    0.271862  0.419759       0.190034
# 45    VA  0.041872  0.046429   0.096023    0.177842  0.637827       0.088301
# 46    VT  0.045357  0.087786   0.069286    0.137643  0.660000       0.133143
# 47    WA  0.037897  0.038872   0.070667    0.182410  0.669872       0.076769
# 48    WI  0.086833  0.102042   0.145361    0.232319  0.433500       0.188875
# 49    WV  0.086073  0.077073   0.136055    0.218436  0.482418       0.163145
# 50    WY  0.151609  0.157000   0.123000    0.232000  0.336435       0.308609
#
#     mask_positive
# 0        0.788964
# 1        0.690657
# 2        0.683493
# 3        0.802333
# 4        0.873241
# 5        0.791766
# 6        0.905875
# 7        0.907000
# 8        0.913333
# 9        0.776851
# 10       0.712107
# 11       0.931600
# 12       0.610909
# 13       0.606682
# 14       0.729569
# 15       0.687141
# 16       0.615057
# 17       0.699392
# 18       0.730813
# 19       0.928429
# 20       0.904583
# 21       0.793625
# 22       0.793687
# 23       0.618655
# 24       0.587096
# 25       0.728110
# 26       0.532679
# 27       0.801630
# 28       0.509057
# 29       0.612763
# 30       0.813900
# 31       0.906333
# 32       0.829697
# 33       0.822235
# 34       0.905210
# 35       0.656534
# 36       0.612169
# 37       0.828611
# 38       0.842627
# 39       0.938000
# 40       0.723087
# 41       0.579169
# 42       0.636716
# 43       0.791224
# 44       0.691621
# 45       0.815669
# 46       0.797643
# 47       0.852282
# 48       0.665819
# 49       0.700855
# 50       0.568435

# %%
# Saving the state DataFrame as state.csv
state.to_csv('./data/state.csv')

# %%
# Found good data on the 2016 election
election = pd.read_csv('./data/2016election.csv')

# %% [markdown]
# I was thinking that we could add this data to our mask data by state. Then we could perform analysis regarding mask sentiment and whether the state is left or right leaning. We can also explore whether a state has negative mask sentiment if they have a relatively low population.

# %%
election.head(2)
# Out:
#      State  votesDem  percD  votesRep  percR  electoralDem  electoralRep  \
# 0  Alabama    729547  34.36   1318255  62.08             0             9
# 1   Alaska    116454  36.55    163387  51.28             0             3
#
#        Pop
# 0  4908620
# 1   734002

# %% [markdown]
# Found a cool module called 'us'. Check it out: https://github.com/unitedstates/python-us

# %%
# Creating a variable containing a dictionary {'state_name': 'state_abbr'}
name_abr_map = us.states.mapping('name', 'abbr')

# %%
election.head(2)
# Out:
#      State  votesDem  percD  votesRep  percR  electoralDem  electoralRep  \
# 0  Alabama    729547  34.36   1318255  62.08             0             9
# 1   Alaska    116454  36.55    163387  51.28             0             3
#
#        Pop
# 0  4908620
# 1   734002

# %%
# Should have used .map DOH! Still works
election['State'] = election['State'].apply(lambda x: name_abr_map.get(x))

# %%
# Missing DC @ ix 8
election.head(10)
# Out:
#   State  votesDem  percD  votesRep  percR  electoralDem  electoralRep  \
# 0    AL    729547  34.36   1318255  62.08             0             9
# 1    AK    116454  36.55    163387  51.28             0             3
# 2    AZ   1161167  45.13   1252401  48.67             0            11
# 3    AR    380494  33.65    684872  60.57             0             6
# 4    CA   8753788  61.73   4483810  31.62            55             0
# 5    CO   1338870  48.16   1202484  43.25             9             0
# 6    CT    897572  54.57    673215  40.93             7             0
# 7    DE    235603  53.09    185127  41.72             3             0
# 8  None    282830  90.48     12723   4.07             3             0
# 9    FL   4504975  47.82   4617886  49.02             0            29
#
#         Pop
# 0   4908620
# 1    734002
# 2   7378490
# 3   3039000
# 4  39937500
# 5   5845530
# 6   3563080
# 7    982895
# 8    720687
# 9  21993000

# %%
# Fixing the None value
election.loc[8, 'State'] = 'DC'

# %%
# Merging the two dataframes
state_mask_election = pd.merge(state, election, left_on='STATE', right_on='State')

# %%
# Dropping redundant columns
state_mask_election = state_mask_election.drop(columns=['index', 'State'])

# %%
# Checking
state_mask_election.head()
# Out:
#   STATE     NEVER    RARELY  SOMETIMES  FREQUENTLY    ALWAYS  mask_negative  \
# 0    AK  0.053429  0.064643   0.092821    0.326393  0.462571       0.118071
# 1    AL  0.081567  0.081090   0.146612    0.215343  0.475313       0.162657
# 2    AR  0.090920  0.087253   0.138360    0.220627  0.462867       0.178173
# 3    AZ  0.049667  0.053200   0.094667    0.147333  0.655000       0.102867
# 4    CA  0.032310  0.030724   0.063690    0.158603  0.714638       0.063034
#
#    mask_positive  votesDem  percD  votesRep  percR  electoralDem  \
# 0       0.788964    116454  36.55    163387  51.28             0
# 1       0.690657    729547  34.36   1318255  62.08             0
# 2       0.683493    380494  33.65    684872  60.57             0
# 3       0.802333   1161167  45.13   1252401  48.67             0
# 4       0.873241   8753788  61.73   4483810  31.62            55
#
#    electoralRep       Pop
# 0             3    734002
# 1             9   4908620
# 2             6   3039000
# 3            11   7378490
# 4             0  39937500

# %%
# Creating blue and red column. 
state_mask_election['blue'] = where(state_mask_election['electoralDem'] > 0, 1, 0)
state_mask_election['red'] = where(state_mask_election['electoralRep'] > 0, 1, 0)

# %%
state_mask_election.head(2)
# Out:
#   STATE     NEVER    RARELY  SOMETIMES  FREQUENTLY    ALWAYS  mask_negative  \
# 0    AK  0.053429  0.064643   0.092821    0.326393  0.462571       0.118071
# 1    AL  0.081567  0.081090   0.146612    0.215343  0.475313       0.162657
#
#    mask_positive  votesDem  percD  votesRep  percR  electoralDem  \
# 0       0.788964    116454  36.55    163387  51.28             0
# 1       0.690657    729547  34.36   1318255  62.08             0
#
#    electoralRep      Pop  blue  red
# 0             3   734002     0    1
# 1             9  4908620     0    1

# %%
# Saving the new state_mask_election DataFrame as sme.csv 
state_mask_election.to_csv('./data/sme.csv')

# %% [markdown]
# I felt sme was easier to type although it is not descriptive. Let me know if you want it more descriptive.
