# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from datetime import timedelta

# %%
df = pd.read_csv('../data/covid_metrics_full_time.csv', index_col=0)

# %%
df
# Out:
#              date          state  fips   cases  deaths
# 0      2020-01-21     Washington    53       1       0
# 1      2020-01-22     Washington    53       1       0
# 2      2020-01-23     Washington    53       1       0
# 3      2020-01-24       Illinois    17       1       0
# 4      2020-01-24     Washington    53       1       0
# ...           ...            ...   ...     ...     ...
# 12329  2020-10-12       Virginia    51  159570    3361
# 12330  2020-10-12     Washington    53   98265    2292
# 12331  2020-10-12  West Virginia    54   18281     385
# 12332  2020-10-12      Wisconsin    55  160655    1488
# 12333  2020-10-12        Wyoming    56    7802      54
#
# [12334 rows x 5 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df.set_index('date')

# %%
df['state'].unique()
# Out:
# array(['Washington', 'Illinois', 'California', 'Arizona', 'Massachusetts',
#        'Wisconsin', 'Texas', 'Nebraska', 'Utah', 'Oregon', 'Florida',
#        'New York', 'Rhode Island', 'Georgia', 'New Hampshire',
#        'North Carolina', 'New Jersey', 'Colorado', 'Maryland', 'Nevada',
#        'Tennessee', 'Hawaii', 'Indiana', 'Kentucky', 'Minnesota',
#        'Oklahoma', 'Pennsylvania', 'South Carolina',
#        'District of Columbia', 'Kansas', 'Missouri', 'Vermont',
#        'Virginia', 'Connecticut', 'Iowa', 'Louisiana', 'Ohio', 'Michigan',
#        'South Dakota', 'Arkansas', 'Delaware', 'Mississippi',
#        'New Mexico', 'North Dakota', 'Wyoming', 'Alaska', 'Maine',
#        'Alabama', 'Idaho', 'Montana', 'Puerto Rico', 'Virgin Islands',
#        'Guam', 'West Virginia', 'Northern Mariana Islands'], dtype=object)

# %%
df[df['state'] == 'Idaho'].iloc[-1].name
# Out:
# Timestamp('2020-10-12 00:00:00')

# %%
df[df['state'] == i]['cases'].plot(figsize=(20,8), label=i)
plt.annotate(f'  {i}', xy=((df[df['state'] == i].iloc[-1].name), df[df['state'] == i].iloc[-1]['cases']));

# %%
for i in df['state'].unique():
    df[df['state'] == i]['cases'].plot(figsize=(15,8), label=i)
    plt.annotate(f'  {i}', xy=((df[df['state'] == i].iloc[-1].name), df[df['state'] == i].iloc[-1]['cases']), fontsize=10);
